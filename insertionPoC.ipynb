# %% [markdown]
# <a href="https://colab.research.google.com/github/Candrew21339/CS315/blob/main/insertionPoC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Template for testing Insertion-Sort on small lists, outputing each intermediate step

# %%
import random
import datetime

# %%
def insertion(A, print_flag):
  n = len(A)
  for i in range(1, n):
    key = A[i]
    j = i - 1
    while j >= 0 and A[j] > key:
      A[j + 1] = A[j]
      j = j - 1
      A[j + 1] = key

# %%
def insertion_timed(a):
  global time_results
  print("n=" + str(n))
  start_time = datetime.datetime.now()
  insertion(a, False)
  end_time = datetime.datetime.now()
  time_elapsed = (end_time - start_time).total_seconds()
  print(time_elapsed)

  #for ratio tests
  time_results.append(time_elapsed)

# %%
time_results = []

n=1000
a = list(range(n))
random.shuffle(a)
insertion_timed(a)

n=1000
a = list(range(n))
random.shuffle(a)
insertion_timed(a)

n=2000
a = list(range(n))
random.shuffle(a)
insertion_timed(a)

n=4000
a = list(range(n))
random.shuffle(a)
insertion_timed(a)

n=8000
a = list(range(n))
random.shuffle(a)
insertion_timed(a)

n=16000
a = list(range(n))
random.shuffle(a)
insertion_timed(a)

N_values = [1000, 2000, 4000, 8000, 16000]


print("ratio test:")

for i in range(1, len(time_results)):
    ratio = time_results[i] / time_results[i-1]
    n_ratio = (N_values[i] / N_values[i-1])
    print(f"T({2**(i) * 1000}) / T({2**(i-1) * 1000}) = {ratio:.4f}")

print("Average ratio")

# Take the sum of all ratios, divide it by the number of ratios.
print(sum(time_results[i] / time_results[i-1] for i in range(1, len(time_results))) / (len(time_results) - 1))
# Out:
# n=1000
# 0.03102
# n=1000
# 0.028846
# n=2000
# 0.148766
# n=4000
# 0.51484
# n=8000
# 2.251396
# n=16000
# 9.419229
# ratio test:
# T(2000) / T(1000) = 0.9299
# T(4000) / T(2000) = 5.1572
# T(8000) / T(4000) = 3.4607
# T(16000) / T(8000) = 4.3730
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2777666656.py in <cell line: 0>()
#      38 for i in range(1, len(time_results)):
#      39     ratio = time_results[i] / time_results[i-1]
# ---> 40     n_ratio = (N_values[i] / N_values[i-1])
#      41     print(f"T({2**(i) * 1000}) / T({2**(i-1) * 1000}) = {ratio:.4f}")
#      42
#
# IndexError: list index out of range

# %%
N=8
A = list(range(N))

random.shuffle(A)

print(A)
insertion(A,True)
print(A)
# Out:
# [1, 3, 4, 7, 2, 6, 0, 5]
# [0, 1, 2, 3, 4, 5, 6, 7]
