# %% [markdown]
# <a href="https://colab.research.google.com/github/Candrew21339/CS315/blob/main/Quickselect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import datetime

def quickselect(A, i):
    # Select ith smallest element (1-indexed)
    if len(A) == 1:
        return A[0]
    pivot = random.choice(A)
    lows = [x for x in A if x < pivot]
    highs = [x for x in A if x > pivot]
    pivots = [x for x in A if x == pivot]
    if i <= len(lows):
        return quickselect(lows, i)
    elif i <= len(lows) + len(pivots):
        return pivot
    else:
        return quickselect(highs, i - len(lows) - len(pivots))

def quickselect_timed(a, i):
    global time_results
    n = len(a)
    print("n=" + str(n))
    start_time = datetime.datetime.now()
    result = quickselect(a.copy(), i)
    end_time = datetime.datetime.now()
    time_elapsed = (end_time - start_time).total_seconds()
    print(f"Time: {time_elapsed}, Result: {result}")
    time_results.append(time_elapsed)

# %%
# Test on random data
print("Random Data")
time_results = []
N_values = [1000, 2000, 4000, 8000, 16000]

for n in N_values:
    a = list(range(n))
    random.shuffle(a)
    quickselect_timed(a, n // 2)

print("\nRatio test (O(n) expected):")
for n, t in zip(N_values, time_results):
    ratio = t / n
    print(f"n={n:5d}: T(n)/n = {ratio:.9f}")
# Out:
# Random Data
# n=1000
# Time: 0.000528, Result: 499
# n=2000
# Time: 0.000951, Result: 999
# n=4000
# Time: 0.001299, Result: 1999
# n=8000
# Time: 0.001815, Result: 3999
# n=16000
# Time: 0.003552, Result: 7999
#
# Ratio test (O(n) expected):
# n= 1000: T(n)/n = 0.000000528
# n= 2000: T(n)/n = 0.000000475
# n= 4000: T(n)/n = 0.000000325
# n= 8000: T(n)/n = 0.000000227
# n=16000: T(n)/n = 0.000000222

# %%
# Test on sorted data
print("Sorted Data")
time_results = []
N_values = [1000, 2000, 4000, 8000, 16000]

for n in N_values:
    a = list(range(n))
    quickselect_timed(a, n // 2)

print("\nRatio test (O(n) expected):")
for n, t in zip(N_values, time_results):
    ratio = t / n
    print(f"n={n:5d}: T(n)/n = {ratio:.9f}")
# Out:
# Sorted Data
# n=1000
# Time: 0.000447, Result: 499
# n=2000
# Time: 0.000594, Result: 999
# n=4000
# Time: 0.000655, Result: 1999
# n=8000
# Time: 0.002988, Result: 3999
# n=16000
# Time: 0.0029, Result: 7999
#
# Ratio test (O(n) expected):
# n= 1000: T(n)/n = 0.000000447
# n= 2000: T(n)/n = 0.000000297
# n= 4000: T(n)/n = 0.000000164
# n= 8000: T(n)/n = 0.000000374
# n=16000: T(n)/n = 0.000000181

# %%
# Test on reverse sorted data
print("Reverse Sorted Data")
time_results = []
N_values = [1000, 2000, 4000, 8000, 16000]

for n in N_values:
    a = list(range(n, 0, -1))
    quickselect_timed(a, n // 2)

print("\nRatio test (O(n) expected):")
for n, t in zip(N_values, time_results):
    ratio = t / n
    print(f"n={n:5d}: T(n)/n = {ratio:.9f}")
# Out:
# Reverse Sorted Data
# n=1000
# Time: 0.00038, Result: 500
# n=2000
# Time: 0.000254, Result: 1000
# n=4000
# Time: 0.001052, Result: 2000
# n=8000
# Time: 0.001525, Result: 4000
# n=16000
# Time: 0.002487, Result: 8000
#
# Ratio test (O(n) expected):
# n= 1000: T(n)/n = 0.000000380
# n= 2000: T(n)/n = 0.000000127
# n= 4000: T(n)/n = 0.000000263
# n= 8000: T(n)/n = 0.000000191
# n=16000: T(n)/n = 0.000000155

# %%
# Test on all same elements
print("\n=== ALL SAME ELEMENTS ===")
time_results = []
N_values = [1000, 2000, 4000, 8000, 16000]

for n in N_values:
    a = [5] * n
    quickselect_timed(a, n // 2)

print("\nRatio test (O(n) expected):")
for n, t in zip(N_values, time_results):
    ratio = t / n
    print(f"n={n:5d}: T(n)/n = {ratio:.9f}")
# Out:
# === ALL SAME ELEMENTS ===
# n=1000
# Time: 7.6e-05, Result: 5
# n=2000
# Time: 0.000142, Result: 5
# n=4000
# Time: 0.000239, Result: 5
# n=8000
# Time: 0.000495, Result: 5
# n=16000
# Time: 0.000989, Result: 5
#
# Ratio test (O(n) expected):
# n= 1000: T(n)/n = 0.000000076
# n= 2000: T(n)/n = 0.000000071
# n= 4000: T(n)/n = 0.000000060
# n= 8000: T(n)/n = 0.000000062
# n=16000: T(n)/n = 0.000000062
