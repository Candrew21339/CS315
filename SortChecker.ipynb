# %% [markdown]
# <a href="https://colab.research.google.com/github/Candrew21339/CS315/blob/main/SortChecker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Template for testing Insertion-Sort on small lists, outputing each intermediate step

# %%
import random
import datetime

# %%
def sort_timed(a):
  global time_results
  print("n=" + str(n))
  start_time = datetime.datetime.now()
  a.sort()
  end_time = datetime.datetime.now()
  time_elapsed = (end_time - start_time).total_seconds()
  print(time_elapsed)

  #for ratio tests
  time_results.append(time_elapsed)

def sorted_timed(a):
  global time_results
  print("n=" + str(n))
  start_time = datetime.datetime.now()
  a = sorted(a)
  end_time = datetime.datetime.now()
  time_elapsed = (end_time - start_time).total_seconds()
  print(time_elapsed)

  #for ratio tests
  time_results.append(time_elapsed)

# %%
#sort random
time_results = []

n=1000
a = list(range(n))
random.shuffle(a)
sort_timed(a)

n=2000
a = list(range(n))
random.shuffle(a)
sort_timed(a)

n=4000
a = list(range(n))
random.shuffle(a)
sort_timed(a)

n=8000
a = list(range(n))
random.shuffle(a)
sort_timed(a)

n=16000
a = list(range(n))
random.shuffle(a)
sort_timed(a)


N_values = [1000, 2000, 4000, 8000, 16000]


print("ratio test:")

for i in range(1, len(time_results)):
    ratio = time_results[i] / time_results[i-1]
    n_ratio = (N_values[i] / N_values[i-1])
    print(f"T({2**(i) * 1000}) / T({2**(i-1) * 1000}) = {ratio:.4f}")

print("Average ratio")

# Take the sum of all ratios, divide it by the number of ratios.
print(sum(time_results[i] / time_results[i-1] for i in range(1, len(time_results))) / (len(time_results) - 1))
# Out:
# n=1000
# 0.000129
# n=2000
# 0.00033
# n=4000
# 0.000578
# n=8000
# 0.001326
# n=16000
# 0.002971
# ratio test:
# T(2000) / T(1000) = 2.5581
# T(4000) / T(2000) = 1.7515
# T(8000) / T(4000) = 2.2941
# T(16000) / T(8000) = 2.2406
# Average ratio
# 2.2110863714488884

# %%
#sort sorted
time_results = []

n=1000
a = list(range(n))
sort_timed(a)

n=2000
a = list(range(n))
sort_timed(a)

n=4000
a = list(range(n))
sort_timed(a)

n=8000
a = list(range(n))
sort_timed(a)

n=16000
a = list(range(n))
sort_timed(a)


N_values = [1000, 2000, 4000, 8000, 16000]


print("ratio test:")

for i in range(1, len(time_results)):
    ratio = time_results[i] / time_results[i-1]
    n_ratio = (N_values[i] / N_values[i-1])
    print(f"T({2**(i) * 1000}) / T({2**(i-1) * 1000}) = {ratio:.4f}")

print("Average ratio")

# Take the sum of all ratios, divide it by the number of ratios.
print(sum(time_results[i] / time_results[i-1] for i in range(1, len(time_results))) / (len(time_results) - 1))
# Out:
# n=1000
# 1.7e-05
# n=2000
# 1.1e-05
# n=4000
# 1.9e-05
# n=8000
# 4.6e-05
# n=16000
# 9.6e-05
# ratio test:
# T(2000) / T(1000) = 0.6471
# T(4000) / T(2000) = 1.7273
# T(8000) / T(4000) = 2.4211
# T(16000) / T(8000) = 2.0870
# Average ratio
# 1.7205851760300543

# %%
#sorted random
time_results = []

n=1000
a = list(range(n))
random.shuffle(a)
sorted_timed(a)

n=2000
a = list(range(n))
random.shuffle(a)
sorted_timed(a)

n=4000
a = list(range(n))
random.shuffle(a)
sorted_timed(a)

n=8000
a = list(range(n))
random.shuffle(a)
sorted_timed(a)

n=16000
a = list(range(n))
random.shuffle(a)
sorted_timed(a)


N_values = [1000, 2000, 4000, 8000, 16000]


print("ratio test:")

for i in range(1, len(time_results)):
    ratio = time_results[i] / time_results[i-1]
    n_ratio = (N_values[i] / N_values[i-1])
    print(f"T({2**(i) * 1000}) / T({2**(i-1) * 1000}) = {ratio:.4f}")

print("Average ratio")

# Take the sum of all ratios, divide it by the number of ratios.
print(sum(time_results[i] / time_results[i-1] for i in range(1, len(time_results))) / (len(time_results) - 1))
# Out:
# n=1000
# 0.000151
# n=2000
# 0.000285
# n=4000
# 0.000609
# n=8000
# 0.001369
# n=16000
# 0.003101
# ratio test:
# T(2000) / T(1000) = 1.8874
# T(4000) / T(2000) = 2.1368
# T(8000) / T(4000) = 2.2479
# T(16000) / T(8000) = 2.2652
# Average ratio
# 2.134340956897761

# %%
#sorted sorted
time_results = []

n=1000
a = list(range(n))
sorted_timed(a)

n=2000
a = list(range(n))
sorted_timed(a)

n=4000
a = list(range(n))
sorted_timed(a)

n=8000
a = list(range(n))
sorted_timed(a)

n=16000
a = list(range(n))
sorted_timed(a)


N_values = [1000, 2000, 4000, 8000, 16000]


print("ratio test:")

for i in range(1, len(time_results)):
    ratio = time_results[i] / time_results[i-1]
    n_ratio = (N_values[i] / N_values[i-1])
    print(f"T({2**(i) * 1000}) / T({2**(i-1) * 1000}) = {ratio:.4f}")

print("Average ratio")

# Take the sum of all ratios, divide it by the number of ratios.
print(sum(time_results[i] / time_results[i-1] for i in range(1, len(time_results))) / (len(time_results) - 1))
